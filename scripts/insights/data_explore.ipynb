# %%
import sys
import pandas as pd
sys.path.append('..')
from common.base import session
import numpy as np
import matplotlib.pyplot as plt

# %%
data = session.execute('''
SELECT trip_id,lat,long FROM daily_trip WHERE trip_id = '00922df3be5a4589ab385d0c2da2dd81'
''')
df = pd.DataFrame(data, columns=['trip_id','lat','lon'])

# %%
BBox = (df.lon.min(), df.lon.max(), df.lat.min(), df.lat.max())
lat = df['lat'].to_numpy()
long = df['lon'].to_numpy()
lat
# Out:
# array(['31.8125', '31.8125', '31.8125', ..., '31.8125', '31.8125',
#        '31.8125'], dtype=object)

# %%
import pandas as pd
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2034">Loading BokehJS ...</span>
#     </div>

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv('GOOGLE_API_KEY')

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Pays de Gex', 
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
#lat, lon = 31.8125, -86.8825
p = plot(lat, lon)
# Out:
#   <div class="bk-root" id="9336dd80-243c-4ffa-98c9-0ff717cfdb91" data-root-id="2036"></div>

# %%
from bokeh.models import ColumnDataSource

def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Pays de Gex', 
             width=bokeh_width, height=bokeh_height)
    # definition of the column data source: 
    source = ColumnDataSource(data=df)
    print(source)
    # see how we specify the x and y columns as strings, 
    # and how to declare as a source the ColumnDataSource:
    center = p.circle('lon', 'lat', size=4, alpha=0.2, 
                      color='yellow', source=source)
    show(p)
    return p

p = plot(lat, lon, map_type='roadmap')
# Out:
# ColumnDataSource(id='3756', ...)
#   <div class="bk-root" id="2f136a82-1c38-467b-9987-e78e32cda6a6" data-root-id="3725"></div>

# %%
map_options = GMapOptions(lat=31.8125, lng=-86.8825, map_type="roadmap", zoom=10)

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
p = gmap("GOOGLE_API_KEY", map_options, title="Austin")

source = ColumnDataSource(
    data=dict(lat=df['lat'],
              lon=df['lon'])
)

#p.circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, source=source)

show(p)
# Out:
#   <div class="bk-root" id="7a7d85da-bd80-4d3d-904d-3e6355b86298" data-root-id="5737"></div>

# %%
import plotly.express as px
fig = px.scatter_geo(df,lat='lat',lon='lon', hover_name="trip_id")
fig.update_layout(title = 'World map', title_x=0.5)
fig.show()
